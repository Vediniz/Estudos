# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
URL ='https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

r = requests.get(URL)


r.status_code
# Out:
# 200

# %%
# 2) Seu código aqui
data = r.json()

print(data)
rj = requests.get('https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado')
rj = rj.json()
# Out:
# {'items': [{'id_pleito': 9101, 'tipo_interessado': 'Município', 'interessado': 'Piraí', 'cod_ibge': 3304003, 'uf': 'RJ', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.000903/2008-07', 'data_protocolo': '2008-04-02T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Caminho da Escola 2', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 367500, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '13/08/2008'}, {'id_pleito': 6975, 'tipo_interessado': 'Município', 'interessado': 'Rio de Janeiro', 'cod_ibge': 3304557, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000471/2007-45', 'data_protocolo': '2007-04-30T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Saneamento básico', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 7262240, 'pvl_assoc_divida': 1, 'pvl
# ...

# %%
df['status'].value_counts()
# Out:
# Deferido                                                 102
# Arquivado                                                 53
# Encaminhado à PGFN com manifestação técnica favorável     45
# Regularizado                                              25
# Arquivado por decurso de prazo                            24
# Deferido (PVL-IF)                                         14
# Arquivado a pedido                                         7
# Em retificação pelo interessado                            2
# Pendente de regularização                                  1
# Em retificação pelo interessado (PVL-IF)                   1
# Em retificação pelo credor                                 1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
df = pd.DataFrame(data['items'])
df_rj = pd.DataFrame(rj['items'])

df = pd.concat([df,df_rj]).drop_duplicates()
df
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        9101        Município           Piraí   3304003  RJ
# 1        6975        Município  Rio de Janeiro   3304557  RJ
# 2        7062        Município     Nova Iguaçu   3303500  RJ
# 3        7488        Município        Mesquita   3302858  RJ
# 4       11419        Município  Rio de Janeiro   3304557  RJ
# ..        ...              ...             ...       ...  ..
# 47      21388           Estado  Rio de Janeiro        33  RJ
# 48       9750           Estado  Rio de Janeiro        33  RJ
# 49       8556           Estado  Rio de Janeiro        33  RJ
# 50      10002           Estado  Rio de Janeiro        33  RJ
# 51       7080           Estado  Rio de Janeiro        33  RJ
#
#                  num_pvl                                             status  \
# 0                   None                                          Arquivado
# 1                   None                                           Deferido
# ...

# %%
df['ano_stts'] = df['data_status']

df['ano_stts'] = df['ano_stts'].str.slice(start = 6, stop = None)
df
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        9101        Município           Piraí   3304003  RJ
# 1        6975        Município  Rio de Janeiro   3304557  RJ
# 2        7062        Município     Nova Iguaçu   3303500  RJ
# 3        7488        Município        Mesquita   3302858  RJ
# 4       11419        Município  Rio de Janeiro   3304557  RJ
# ..        ...              ...             ...       ...  ..
# 47      21388           Estado  Rio de Janeiro        33  RJ
# 48       9750           Estado  Rio de Janeiro        33  RJ
# 49       8556           Estado  Rio de Janeiro        33  RJ
# 50      10002           Estado  Rio de Janeiro        33  RJ
# 51       7080           Estado  Rio de Janeiro        33  RJ
#
#                  num_pvl                                             status  \
# 0                   None                                          Arquivado
# 1                   None                                           Deferido
# ...

# %%
df['ano_stts'].value_counts()
# Out:
# 2008    39
# 2007    29
# 2012    24
# 2014    24
# 2010    22
# 2013    22
# 2009    18
# 2019    17
# 2011    16
# 2020    15
# 2015     9
# 2016     8
# 2002     8
# 2006     6
# 2021     5
# 2017     5
# 2018     4
# 2022     2
# 2004     1
# 2003     1
# Name: ano_stts, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
def receber_uf(uf, x):
    df_r = df.loc[(df['tipo_interessado'] == x) & (df['uf'] == uf)]
    
    return df_r

uf = input('Digite o UF: ').upper()
interesse = input('Digite o Interesse(Estado/Município: )')
receber_uf(uf, interesse)
# Out:
# Digite o UF: rj
# Digite o Interesse(Estado/Município: )Estado
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        7057           Estado  Rio de Janeiro        33  RJ
# 1        7084           Estado  Rio de Janeiro        33  RJ
# 2       13629           Estado  Rio de Janeiro        33  RJ
# 3       13483           Estado  Rio de Janeiro        33  RJ
# 4        9102           Estado  Rio de Janeiro        33  RJ
# 5       22594           Estado  Rio de Janeiro        33  RJ
# 6        9050           Estado  Rio de Janeiro        33  RJ
# 7        6660           Estado  Rio de Janeiro        33  RJ
# 8       13271           Estado  Rio de Janeiro        33  RJ
# 9        6833           Estado  Rio de Janeiro        33  RJ
# 10       5918           Estado  Rio de Janeiro        33  RJ
# 11      12410           Estado  Rio de Janeiro        33  RJ
# 12       9898           Estado  Rio de Janeiro        33  RJ
# ...

# %% [markdown]
# * Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com status em 'Arquivado por decurso de prazo' estão registradas?
# * Qual é o município da Bahia com mais solicitações deferidas?
# * Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
r = requests.get(  'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado')


data = r.json()

df_mg = pd.DataFrame(data['items'] )

df_mg['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Arquivado por decurso de prazo                            1
# Indeferido                                                1
# Name: status, dtype: int64

# %%
df_mg.loc[df_mg['status'] == 'Arquivado por decurso de prazo']
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 6      20534           Estado  Minas Gerais        31  MG
#
#                 num_pvl                          status          num_processo  \
# 6  00000.000000/2017-69  Arquivado por decurso de prazo  17944.001113/2015-60
#
#          data_protocolo                tipo_operacao finalidade  \
# 6  2017-07-26T03:00:00Z  Operação contratual interna       PMAE
#
#                        tipo_credor  \
# 6  Instituição Financeira Nacional
#
#                                               credor moeda      valor  \
# 6  Banco Nacional de Desenvolvimento Econômico e ...  Real  7668000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 6                 0                      0  16/03/2018

# %%
ba_Est = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
ba_Mun =  'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio'

ba_est = requests.get(ba_Est)
ba_mun = requests.get(ba_Mun)

ba_est = ba_est.json()
ba_mun = ba_mun.json()

# %%
df_ba_es = pd.DataFrame(ba_est['items'])
df_ba_mu = pd.DataFrame(ba_mun['items'])

df_ba = pd.concat([df_ba_es, df_ba_mu]).drop_duplicates()

# %%
df_ba
# Out:
#      id_pleito tipo_interessado           interessado  cod_ibge  uf num_pvl  \
# 0         6768           Estado                 Bahia        29  BA    None
# 1         7078           Estado                 Bahia        29  BA    None
# 2        10431           Estado                 Bahia        29  BA    None
# 3        18515           Estado                 Bahia        29  BA    None
# 4        10198           Estado                 Bahia        29  BA    None
# ..         ...              ...                   ...       ...  ..     ...
# 841       6771        Município           Baianópolis   2902500  BA    None
# 842       6986        Município                Itatim   2916856  BA    None
# 843       7806        Município           Baianópolis   2902500  BA    None
# 844      12661        Município             Jeremoabo   2918100  BA    None
# 845      12858        Município  Salinas da Margarida   2927309  BA    None
#
# ...

# %%
df_def_ba = df_ba.loc[df_ba['status'] == 'Deferido']

df_def_ba['interessado'].value_counts()
# Out:
# Bahia                     49
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Lauro de Freitas          10
# Camaçari                  10
#                           ..
# São Sebastião do Passé     1
# Nazaré                     1
# Aracatu                    1
# Nova Itarana               1
# Itaparica                  1
# Name: interessado, Length: 173, dtype: int64

# %%
df_est_ba = df_ba.loc[df_ba['tipo_interessado'] == 'Estado']

df_est_ba
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0        6768           Estado       Bahia        29  BA    None
# 1        7078           Estado       Bahia        29  BA    None
# 2       10431           Estado       Bahia        29  BA    None
# 3       18515           Estado       Bahia        29  BA    None
# 4       10198           Estado       Bahia        29  BA    None
# ..        ...              ...         ...       ...  ..     ...
# 76      18589           Estado       Bahia        29  BA    None
# 77      18595           Estado       Bahia        29  BA    None
# 78      18633           Estado       Bahia        29  BA    None
# 79       8858           Estado       Bahia        29  BA    None
# 80      18531           Estado       Bahia        29  BA    None
#
#                                                status          num_processo  \
# 0   Encaminhado à PGFN com manifestação técnica fa...  17944.000425/2010-41
# ...

# %%
df_est_ba.to_csv('interessado_estado_ba.csv')
